# %%
# %load_ext autoreload
# %autoreload 2

from datetime import datetime
from pathlib import Path

import pandas as pd
from loguru import logger

from plex_pipe.core_cutting.channel_scanner import discover_channels
from plex_pipe.core_cutting.controller import CorePreparationController
from plex_pipe.core_cutting.file_io import LocalFileStrategy
from plex_pipe.utils.config_loaders import load_analysis_settings
# Out:
# c:\Users\KMK280\AppData\Local\miniconda3\envs\sdata-env\Lib\site-packages\dask\dataframe\__init__.py:31: FutureWarning: The legacy Dask DataFrame implementation is deprecated and will be removed in a future version. Set the configuration option `dataframe.query-planning` to `True` or None to enable the new Dask Dataframe implementation and silence this warning.
#   warnings.warn(
# c:\Users\KMK280\AppData\Local\miniconda3\envs\sdata-env\Lib\site-packages\xarray_schema\__init__.py:1: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import DistributionNotFound, get_distribution

# %% [markdown]
# ### Load analysis settings

# %%
# load analysis configuration
settings_path = r'C:\sdata_toy_example/analysis_settings_LCB004-N-P_todel.yaml'

settings = load_analysis_settings(settings_path)
settings
# Out:
# 2025-11-19 23:30:51.978 | WARNING  | plex_pipe.processors.base:_log_missing_optional_params:51 - InstansegSegmenter.Params: Parameter overlap not provided. Using default value: 80.
# AnalysisConfig(general=GeneralSettings(image_dir='/mnt/r/CellDive/LCB004-N-P/LCB004-N-P_Final', analysis_name='example_analysis', local_analysis_dir='/mnt/c/sdata_toy_example', remote_analysis_dir='/ix1/kkedziora', log_dir=None), core_detection=CoreDetectionSettings(detection_image='LCB004-N-P_1.0.4_R000_DAPI__FINAL_F.ome.tif', core_info_file_path=None, im_level=6, min_area=2000, max_area=10000, min_iou=0.8, min_st=0.9, min_int=15, frame=4), core_cutting=CoreCuttingSettings(cores_dir_tif=None, cores_dir_output=None, include_channels=None, exclude_channels=None, use_markers=['DAPI', 'ECad'], ignore_markers=['Antibody1'], margin=0, mask_value=0, transfer_cleanup_enabled=False, core_cleanup_enabled=False), additional_elements=[NormalizeStep(category='image_filter', type='normalize', input='DAPI', output='DAPI_norm', keep=False, parameters=Params(low=1.0, high=99.8)), NormalizeStep(category='image_filter', type='normalize', input='ECad', output='ECad_norm', keep=False, parameters=Params(low=1.0, high=99.8)), InstansegStep(category='object_segmenter', type='instanseg', input=['DAPI_norm', 'ECad_norm'], output=['instanseg_nucleus', 'instanseg_cell'], keep=True, parameters=Params(model='fluorescence_nuclei_and_cells', pixel_size=0.3, resolve_cell_and_nucleus=True, cleanup_fragments=True, clean_cache=True, normalise=False, overlap=80)), RingStep(category='mask_builder', type='ring', input=['instanseg_nucleus'], output='ring', keep=True, parameters=Params(outer=8, inner=2)), SubtractStep(category='mask_builder', type='subtract', input=['instanseg_cell', 'instanseg_nucleus'], output='cytoplasm', keep=True, parameters={})], qc=QcSettings(prefix='qc_exclude'), quant=[QuantTask(name='instanseg_table', masks={'nucleus': 'instanseg_nucleus', 'cell': 'instanseg_cell', 'ring': 'ring', 'cyto': 'cytoplasm'}, layer_connection='instanseg_cell')], sdata_storage=StorageSettings(chunk_size=[1, 512, 512], max_pyramid_level=3, downscale=2), analysis_dir=WindowsPath('/mnt/c/sdata_toy_example/example_analysis'), temp_dir=WindowsPath('/mnt/c/sdata_toy_example/example_analysis/temp'), log_dir_path=WindowsPath('/mnt/c/sdata_toy_example/example_analysis/logs'), core_info_file_path=WindowsPath('/mnt/c/sdata_toy_example/example_analysis/cores.csv'), cores_dir_tif_path=WindowsPath('/mnt/c/sdata_toy_example/example_analysis/temp'), cores_dir_output_path=WindowsPath('/mnt/c/sdata_toy_example/example_analysis/cores'))

# %% [markdown]
# ### Define the logger

# %%
log_file = settings.log_dir_path / f"cores_cutting_{datetime.now():%Y-%m-%d_%H-%M-%S}.log"

logger.remove()
l = logger.add(lambda msg: print(msg, end=""))
l = logger.add(log_file, level="DEBUG", enqueue=True)

# %% [markdown]
# ### Define cores for processing

# %%
df_path = settings.core_info_file_path.with_suffix('.pkl')

df = pd.read_pickle(df_path)
df.head()
# Out:
#   roi_name  row_start  row_stop  column_start  column_stop  poly_type  \
# 0  Core_000    14208.0   14784.0       70656.0      71296.0  rectangle
#
#                                     polygon_vertices
# 0  [[14208.0, 71296.0], [14784.0, 71296.0], [1478...

# %%
# # create a subset of cores (optional)
# df = df[:1]
# df
# Out:
#   roi_name  row_start  row_stop  column_start  column_stop poly_type  \
# 0  Core_000     1984.0   49408.0         192.0      39296.0   polygon
#
#                                     polygon_vertices
# 0  [[11328.0, 15296.0], [6336.0, 16064.0], [2624....

# %% [markdown]
# ## Local files

# %%
channel_map = discover_channels(Path(settings.general.image_dir),
                                include_channels=settings.core_cutting.include_channels,
                                exclude_channels=settings.core_cutting.exclude_channels,
                                use_markers=settings.core_cutting.use_markers,
                                ignore_markers=settings.core_cutting.ignore_markers)
# Out:
# 2025-11-18 14:01:28.557 | INFO     | plex_pipe.core_cutting.channel_scanner:scan_channels_from_list:76 - Discovered 19 channels:
# 2025-11-18 14:01:28.559 | INFO     | plex_pipe.core_cutting.channel_scanner:scan_channels_from_list:78 - 001_AP2B <- R:\CellDive\LCB004-N-P\LCB004-N-P_Final\LCB004-N-P_1.0.4_R000_Cy5_AP2B-AF647_FINAL_AFR_F.ome.tif
# 2025-11-18 14:01:28.559 | INFO     | plex_pipe.core_cutting.channel_scanner:scan_channels_from_list:78 - 001_DAPI <- R:\CellDive\LCB004-N-P\LCB004-N-P_Final\LCB004-N-P_1.0.4_R000_DAPI__FINAL_F.ome.tif
# 2025-11-18 14:01:28.560 | INFO     | plex_pipe.core_cutting.channel_scanner:scan_channels_from_list:78 - 001_FOXA1 <- R:\CellDive\LCB004-N-P\LCB004-N-P_Final\LCB004-N-P_1.0.4_R000_Cy3_FOXA1-AF555_FINAL_AFR_F.ome.tif
# 2025-11-18 14:01:28.561 | INFO     | plex_pipe.core_cutting.channel_scanner:scan_channels_from_list:78 - 002_DAPI <- R:\CellDive\LCB004-N-P\LCB004-N-P_Final\LCB004-N-P_2.0.4_R000_DAPI__FINAL_F.ome.tif
# 2025-11-18 14:01:28.561 | INFO     | plex_pipe.core_cutting.channel_scanner:scan_channels_from_list:78 - 002_ER <- R:\CellDive\LCB004-N-P\LCB004-N-P_Final\LCB004-N-P_2.0.4_R000_Cy7_ER-AF750_FINAL_AFR_F.ome.tif
# 2025-11-18 14:01:28.561 | INFO     | plex_pipe.core_cutting.channel_scanner:scan_channels_from_list:78 - 002_GATA3 <- R:\CellDive\LCB004-N-P\LCB004-N-P_Final\LCB004-N-P_2.0.4_R000_Cy3_GATA3-AF546_FINAL_AFR_F.ome.tif
# 2025-11-18 14:01:28.562 | INFO     | plex_pipe.core_cutting.channel_scanner:scan_channels_from_list:78 - 003_AR <- R:\CellDive\LCB004-N-P\LCB004-N-P_Final\LCB004-N-P_3.0.4_R000_Cy3_AR-AF555_FINAL_AFR_F.ome.tif
# 2025-11-18 14:01:28.562 | INFO     | plex_pipe.core_cutting.channel_scanner:scan_channels_from_list:78 - 003_DAPI <- R:\CellDive\LCB004-N-P\LCB004-N-P_Final\LCB004-N-P_3.0.4_R000_DAPI__FINAL_F.ome.tif
# 2025-11-18 14:01:28.564 | INFO     | plex_pipe.core_cutting.channel_scanner:scan_channels_from_list:78 - 003_HER2 <- R:\CellDive\LCB004-N-P\LCB004-N-P_Final\LCB004-N-P_3.0.4_R000_Cy7_HER2-AF750_FINAL_AFR_F.ome.tif
# 2025-11-18 14:01:28.565 | INFO     | plex_pipe.core_cutting.channel_scanner:scan_channels_from_list:78 - 004_DAPI <- R:\CellDive\LCB004-N-P\LCB004-N-P_Final\LCB004-N-P_4.0.4_R000_DAPI__FINAL_F.ome.tif
# 2025-11-18 14:01:28.566 | INFO     | plex_pipe.core_cutting.channel_scanner:scan_channels_from_list:78 - 004_ECad <- R:\CellDive\LCB004-N-P\LCB004-N-P_Final\LCB004-N-P_4.0.4_R000_Cy3_ECad-AF555_FINAL_AFR_F.ome.tif
# 2025-11-18 14:01:28.567 | INFO     | plex_pipe.core_cutting.channel_scanner:scan_channels_from_list:78 - 005_CK14 <- R:\CellDive\LCB004-N-P\LCB004-N-P_Final\LCB004-N-P_5.0.4_R000_Cy7_CK14-AF750_FINAL_AFR_F.ome.tif
# 2025-11-18 14:01:28.567 | INFO     | plex_pipe.core_cutting.channel_scanner:scan_channels_from_list:78 - 005_DAPI <- R:\CellDive\LCB004-N-P\LCB004-N-P_Final\LCB004-N-P_5.0.4_R000_DAPI__FINAL_F.ome.tif
# 2025-11-18 14:01:28.568 | INFO     | plex_pipe.core_cutting.channel_scanner:scan_channels_from_list:78 - 005_SMA <- R:\CellDive\LCB004-N-P\LCB004-N-P_Final\LCB004-N-P_5.0.4_R000_Cy3_SMA-Cy3_FINAL_AFR_F.ome.tif
# 2025-11-18 14:01:28.569 | INFO     | plex_pipe.core_cutting.channel_scanner:scan_channels_from_list:78 - 006_CK818 <- R:\CellDive\LCB004-N-P\LCB004-N-P_Final\LCB004-N-P_6.0.4_R000_Cy3_CK818-AF555_FINAL_AFR_F.ome.tif
# 2025-11-18 14:01:28.570 | INFO     | plex_pipe.core_cutting.channel_scanner:scan_channels_from_list:78 - 006_DAPI <- R:\CellDive\LCB004-N-P\LCB004-N-P_Final\LCB004-N-P_6.0.4_R000_DAPI__FINAL_F.ome.tif
# 2025-11-18 14:01:28.571 | INFO     | plex_pipe.core_cutting.channel_scanner:scan_channels_from_list:78 - 006_ProgRc <- R:\CellDive\LCB004-N-P\LCB004-N-P_Final\LCB004-N-P_6.0.4_R000_Cy7_ProgRc-AF750_FINAL_AFR_F.ome.tif
# 2025-11-18 14:01:28.572 | INFO     | plex_pipe.core_cutting.channel_scanner:scan_channels_from_list:78 - 007_CD45 <- R:\CellDive\LCB004-N-P\LCB004-N-P_Final\LCB004-N-P_7.0.4_R000_Cy7_CD45-AF750_FINAL_AFR_F.ome.tif
# 2025-11-18 14:01:28.572 | INFO     | plex_pipe.core_cutting.channel_scanner:scan_channels_from_list:78 - 007_DAPI <- R:\CellDive\LCB004-N-P\LCB004-N-P_Final\LCB004-N-P_7.0.4_R000_DAPI__FINAL_F.ome.tif
# 2025-11-18 14:01:28.574 | WARNING  | plex_pipe.core_cutting.channel_scanner:scan_channels_from_list:123 - Requested ignore_marker 'Antibody1' not found.
# 2025-11-18 14:01:28.575 | INFO     | plex_pipe.core_cutting.channel_scanner:scan_channels_from_list:128 - Ignoring markers = ['Antibody1']
# 2025-11-18 14:01:28.575 | INFO     | plex_pipe.core_cutting.channel_scanner:scan_channels_from_list:129 - Final filtered channels: ['AP2B', 'DAPI', 'FOXA1', 'ER', 'GATA3', 'AR', 'HER2', 'ECad', 'CK14', 'SMA', 'CK818', 'ProgRc', 'CD45']
# 2025-11-18 14:01:28.576 | INFO     | plex_pipe.core_cutting.channel_scanner:scan_channels_from_list:135 - Final selected channels 13:
# 2025-11-18 14:01:28.577 | INFO     | plex_pipe.core_cutting.channel_scanner:scan_channels_from_list:137 -   Channel: AP2B <- R:\CellDive\LCB004-N-P\LCB004-N-P_Final\LCB004-N-P_1.0.4_R000_Cy5_AP2B-AF647_FINAL_AFR_F.ome.tif
# 2025-11-18 14:01:28.578 | INFO     | plex_pipe.core_cutting.channel_scanner:scan_channels_from_list:137 -   Channel: AR <- R:\CellDive\LCB004-N-P\LCB004-N-P_Final\LCB004-N-P_3.0.4_R000_Cy3_AR-AF555_FINAL_AFR_F.ome.tif
# 2025-11-18 14:01:28.578 | INFO     | plex_pipe.core_cutting.channel_scanner:scan_channels_from_list:137 -   Channel: CD45 <- R:\CellDive\LCB004-N-P\LCB004-N-P_Final\LCB004-N-P_7.0.4_R000_Cy7_CD45-AF750_FINAL_AFR_F.ome.tif
# 2025-11-18 14:01:28.580 | INFO     | plex_pipe.core_cutting.channel_scanner:scan_channels_from_list:137 -   Channel: CK14 <- R:\CellDive\LCB004-N-P\LCB004-N-P_Final\LCB004-N-P_5.0.4_R000_Cy7_CK14-AF750_FINAL_AFR_F.ome.tif
# 2025-11-18 14:01:28.581 | INFO     | plex_pipe.core_cutting.channel_scanner:scan_channels_from_list:137 -   Channel: CK818 <- R:\CellDive\LCB004-N-P\LCB004-N-P_Final\LCB004-N-P_6.0.4_R000_Cy3_CK818-AF555_FINAL_AFR_F.ome.tif
# 2025-11-18 14:01:28.582 | INFO     | plex_pipe.core_cutting.channel_scanner:scan_channels_from_list:137 -   Channel: DAPI <- R:\CellDive\LCB004-N-P\LCB004-N-P_Final\LCB004-N-P_1.0.4_R000_DAPI__FINAL_F.ome.tif
# 2025-11-18 14:01:28.583 | INFO     | plex_pipe.core_cutting.channel_scanner:scan_channels_from_list:137 -   Channel: ECad <- R:\CellDive\LCB004-N-P\LCB004-N-P_Final\LCB004-N-P_4.0.4_R000_Cy3_ECad-AF555_FINAL_AFR_F.ome.tif
# 2025-11-18 14:01:28.583 | INFO     | plex_pipe.core_cutting.channel_scanner:scan_channels_from_list:137 -   Channel: ER <- R:\CellDive\LCB004-N-P\LCB004-N-P_Final\LCB004-N-P_2.0.4_R000_Cy7_ER-AF750_FINAL_AFR_F.ome.tif
# 2025-11-18 14:01:28.584 | INFO     | plex_pipe.core_cutting.channel_scanner:scan_channels_from_list:137 -   Channel: FOXA1 <- R:\CellDive\LCB004-N-P\LCB004-N-P_Final\LCB004-N-P_1.0.4_R000_Cy3_FOXA1-AF555_FINAL_AFR_F.ome.tif
# 2025-11-18 14:01:28.585 | INFO     | plex_pipe.core_cutting.channel_scanner:scan_channels_from_list:137 -   Channel: GATA3 <- R:\CellDive\LCB004-N-P\LCB004-N-P_Final\LCB004-N-P_2.0.4_R000_Cy3_GATA3-AF546_FINAL_AFR_F.ome.tif
# 2025-11-18 14:01:28.586 | INFO     | plex_pipe.core_cutting.channel_scanner:scan_channels_from_list:137 -   Channel: HER2 <- R:\CellDive\LCB004-N-P\LCB004-N-P_Final\LCB004-N-P_3.0.4_R000_Cy7_HER2-AF750_FINAL_AFR_F.ome.tif
# 2025-11-18 14:01:28.586 | INFO     | plex_pipe.core_cutting.channel_scanner:scan_channels_from_list:137 -   Channel: ProgRc <- R:\CellDive\LCB004-N-P\LCB004-N-P_Final\LCB004-N-P_6.0.4_R000_Cy7_ProgRc-AF750_FINAL_AFR_F.ome.tif
# 2025-11-18 14:01:28.587 | INFO     | plex_pipe.core_cutting.channel_scanner:scan_channels_from_list:137 -   Channel: SMA <- R:\CellDive\LCB004-N-P\LCB004-N-P_Final\LCB004-N-P_5.0.4_R000_Cy3_SMA-Cy3_FINAL_AFR_F.ome.tif
# 2025-11-18 14:01:28.588 | INFO     | plex_pipe.core_cutting.channel_scanner:scan_channels_from_list:139 - OME-TIFF files not used in final channel selection 6:
# 2025-11-18 14:01:28.589 | INFO     | plex_pipe.core_cutting.channel_scanner:scan_channels_from_list:141 -   Unused: Channel 002_DAPI <- R:\CellDive\LCB004-N-P\LCB004-N-P_Final\LCB004-N-P_2.0.4_R000_DAPI__FINAL_F.ome.tif
# 2025-11-18 14:01:28.590 | INFO     | plex_pipe.core_cutting.channel_scanner:scan_channels_from_list:141 -   Unused: Channel 003_DAPI <- R:\CellDive\LCB004-N-P\LCB004-N-P_Final\LCB004-N-P_3.0.4_R000_DAPI__FINAL_F.ome.tif
# 2025-11-18 14:01:28.591 | INFO     | plex_pipe.core_cutting.channel_scanner:scan_channels_from_list:141 -   Unused: Channel 004_DAPI <- R:\CellDive\LCB004-N-P\LCB004-N-P_Final\LCB004-N-P_4.0.4_R000_DAPI__FINAL_F.ome.tif
# 2025-11-18 14:01:28.591 | INFO     | plex_pipe.core_cutting.channel_scanner:scan_channels_from_list:141 -   Unused: Channel 005_DAPI <- R:\CellDive\LCB004-N-P\LCB004-N-P_Final\LCB004-N-P_5.0.4_R000_DAPI__FINAL_F.ome.tif
# 2025-11-18 14:01:28.592 | INFO     | plex_pipe.core_cutting.channel_scanner:scan_channels_from_list:141 -   Unused: Channel 006_DAPI <- R:\CellDive\LCB004-N-P\LCB004-N-P_Final\LCB004-N-P_6.0.4_R000_DAPI__FINAL_F.ome.tif
# 2025-11-18 14:01:28.593 | INFO     | plex_pipe.core_cutting.channel_scanner:scan_channels_from_list:141 -   Unused: Channel 007_DAPI <- R:\CellDive\LCB004-N-P\LCB004-N-P_Final\LCB004-N-P_7.0.4_R000_DAPI__FINAL_F.ome.tif

# %%
# # for tests you can request a small set of channels here
# # then send 'short_map' to the controller instead of 'channel_map'
# selected_keys = ["DAPI", "CD3"]
# short_map = {k: channel_map[k] for k in selected_keys if k in channel_map}
# short_map
# Out:
# {'DAPI': 'R:\\CellDive\\BLCA-1B\\BLCA-1B_Final\\BLCA-1B_1.0.4_R000_DAPI__FINAL_F.ome.tif',
#  'CD3': 'R:\\CellDive\\BLCA-1B\\BLCA-1B_Final\\BLCA-1B_11.0.4_R000_Cy3_CD3-AF555_FINAL_AFR_F.ome.tif'}

# %%
strategy = LocalFileStrategy()

controller = CorePreparationController(
    metadata_df = df, # df defines which cores to process
    image_paths = channel_map, # defines which channels to use
    temp_dir = settings.cores_dir_tif_path,
    output_dir = settings.cores_dir_output_path,
    file_strategy = strategy,
    margin = settings.core_cutting.margin,
    mask_value = settings.core_cutting.mask_value,
    max_pyramid_levels = settings.sdata_storage.max_pyramid_level,
    chunk_size = settings.sdata_storage.chunk_size,
    downscale = settings.sdata_storage.chunk_size,
    core_cleanup_enabled = False,
    )


controller.run()
# Out:
# 2025-11-18 14:01:32.214 | INFO     | plex_pipe.core_cutting.controller:run:117 - Starting controller run loop...
# 2025-11-18 14:01:32.223 | INFO     | plex_pipe.core_cutting.controller:run:127 - Channel AP2B file available at R:\CellDive\LCB004-N-P\LCB004-N-P_Final\LCB004-N-P_1.0.4_R000_Cy5_AP2B-AF647_FINAL_AFR_F.ome.tif.
# 2025-11-18 14:01:33.078 | DEBUG    | plex_pipe.core_cutting.controller:cut_channel:93 - Cut and saved core Core_000, channel AP2B.
# 2025-11-18 14:01:33.082 | DEBUG    | plex_pipe.core_cutting.controller:cut_channel:100 - Closed file handle for channel AP2B.
# 2025-11-18 14:01:33.087 | INFO     | plex_pipe.core_cutting.controller:run:127 - Channel DAPI file available at R:\CellDive\LCB004-N-P\LCB004-N-P_Final\LCB004-N-P_1.0.4_R000_DAPI__FINAL_F.ome.tif.
# 2025-11-18 14:01:33.328 | DEBUG    | plex_pipe.core_cutting.controller:cut_channel:93 - Cut and saved core Core_000, channel DAPI.
# 2025-11-18 14:01:33.333 | DEBUG    | plex_pipe.core_cutting.controller:cut_channel:100 - Closed file handle for channel DAPI.
# 2025-11-18 14:01:33.339 | INFO     | plex_pipe.core_cutting.controller:run:127 - Channel FOXA1 file available at R:\CellDive\LCB004-N-P\LCB004-N-P_Final\LCB004-N-P_1.0.4_R000_Cy3_FOXA1-AF555_FINAL_AFR_F.ome.tif.
# 2025-11-18 14:01:33.597 | DEBUG    | plex_pipe.core_cutting.controller:cut_channel:93 - Cut and saved core Core_000, channel FOXA1.
# 2025-11-18 14:01:33.600 | DEBUG    | plex_pipe.core_cutting.controller:cut_channel:100 - Closed file handle for channel FOXA1.
# 2025-11-18 14:01:33.606 | INFO     | plex_pipe.core_cutting.controller:run:127 - Channel ER file available at R:\CellDive\LCB004-N-P\LCB004-N-P_Final\LCB004-N-P_2.0.4_R000_Cy7_ER-AF750_FINAL_AFR_F.ome.tif.
# 2025-11-18 14:01:33.853 | DEBUG    | plex_pipe.core_cutting.controller:cut_channel:93 - Cut and saved core Core_000, channel ER.
# 2025-11-18 14:01:33.858 | DEBUG    | plex_pipe.core_cutting.controller:cut_channel:100 - Closed file handle for channel ER.
# 2025-11-18 14:01:33.866 | INFO     | plex_pipe.core_cutting.controller:run:127 - Channel GATA3 file available at R:\CellDive\LCB004-N-P\LCB004-N-P_Final\LCB004-N-P_2.0.4_R000_Cy3_GATA3-AF546_FINAL_AFR_F.ome.tif.
# 2025-11-18 14:01:34.087 | DEBUG    | plex_pipe.core_cutting.controller:cut_channel:93 - Cut and saved core Core_000, channel GATA3.
# 2025-11-18 14:01:34.091 | DEBUG    | plex_pipe.core_cutting.controller:cut_channel:100 - Closed file handle for channel GATA3.
# 2025-11-18 14:01:34.097 | INFO     | plex_pipe.core_cutting.controller:run:127 - Channel AR file available at R:\CellDive\LCB004-N-P\LCB004-N-P_Final\LCB004-N-P_3.0.4_R000_Cy3_AR-AF555_FINAL_AFR_F.ome.tif.
# 2025-11-18 14:01:34.328 | DEBUG    | plex_pipe.core_cutting.controller:cut_channel:93 - Cut and saved core Core_000, channel AR.
# 2025-11-18 14:01:34.332 | DEBUG    | plex_pipe.core_cutting.controller:cut_channel:100 - Closed file handle for channel AR.
# 2025-11-18 14:01:34.336 | INFO     | plex_pipe.core_cutting.controller:run:127 - Channel HER2 file available at R:\CellDive\LCB004-N-P\LCB004-N-P_Final\LCB004-N-P_3.0.4_R000_Cy7_HER2-AF750_FINAL_AFR_F.ome.tif.
# 2025-11-18 14:01:34.553 | DEBUG    | plex_pipe.core_cutting.controller:cut_channel:93 - Cut and saved core Core_000, channel HER2.
# 2025-11-18 14:01:34.557 | DEBUG    | plex_pipe.core_cutting.controller:cut_channel:100 - Closed file handle for channel HER2.
# 2025-11-18 14:01:34.565 | INFO     | plex_pipe.core_cutting.controller:run:127 - Channel ECad file available at R:\CellDive\LCB004-N-P\LCB004-N-P_Final\LCB004-N-P_4.0.4_R000_Cy3_ECad-AF555_FINAL_AFR_F.ome.tif.
# 2025-11-18 14:01:34.792 | DEBUG    | plex_pipe.core_cutting.controller:cut_channel:93 - Cut and saved core Core_000, channel ECad.
# 2025-11-18 14:01:34.796 | DEBUG    | plex_pipe.core_cutting.controller:cut_channel:100 - Closed file handle for channel ECad.
# 2025-11-18 14:01:34.802 | INFO     | plex_pipe.core_cutting.controller:run:127 - Channel CK14 file available at R:\CellDive\LCB004-N-P\LCB004-N-P_Final\LCB004-N-P_5.0.4_R000_Cy7_CK14-AF750_FINAL_AFR_F.ome.tif.
# 2025-11-18 14:01:35.030 | DEBUG    | plex_pipe.core_cutting.controller:cut_channel:93 - Cut and saved core Core_000, channel CK14.
# 2025-11-18 14:01:35.034 | DEBUG    | plex_pipe.core_cutting.controller:cut_channel:100 - Closed file handle for channel CK14.
# 2025-11-18 14:01:35.040 | INFO     | plex_pipe.core_cutting.controller:run:127 - Channel SMA file available at R:\CellDive\LCB004-N-P\LCB004-N-P_Final\LCB004-N-P_5.0.4_R000_Cy3_SMA-Cy3_FINAL_AFR_F.ome.tif.
# 2025-11-18 14:01:35.291 | DEBUG    | plex_pipe.core_cutting.controller:cut_channel:93 - Cut and saved core Core_000, channel SMA.
# 2025-11-18 14:01:35.296 | DEBUG    | plex_pipe.core_cutting.controller:cut_channel:100 - Closed file handle for channel SMA.
# 2025-11-18 14:01:35.301 | INFO     | plex_pipe.core_cutting.controller:run:127 - Channel CK818 file available at R:\CellDive\LCB004-N-P\LCB004-N-P_Final\LCB004-N-P_6.0.4_R000_Cy3_CK818-AF555_FINAL_AFR_F.ome.tif.
# 2025-11-18 14:01:35.541 | DEBUG    | plex_pipe.core_cutting.controller:cut_channel:93 - Cut and saved core Core_000, channel CK818.
# 2025-11-18 14:01:35.547 | DEBUG    | plex_pipe.core_cutting.controller:cut_channel:100 - Closed file handle for channel CK818.
# 2025-11-18 14:01:35.552 | INFO     | plex_pipe.core_cutting.controller:run:127 - Channel ProgRc file available at R:\CellDive\LCB004-N-P\LCB004-N-P_Final\LCB004-N-P_6.0.4_R000_Cy7_ProgRc-AF750_FINAL_AFR_F.ome.tif.
# 2025-11-18 14:01:35.830 | DEBUG    | plex_pipe.core_cutting.controller:cut_channel:93 - Cut and saved core Core_000, channel ProgRc.
# 2025-11-18 14:01:35.834 | DEBUG    | plex_pipe.core_cutting.controller:cut_channel:100 - Closed file handle for channel ProgRc.
# 2025-11-18 14:01:35.841 | INFO     | plex_pipe.core_cutting.controller:run:127 - Channel CD45 file available at R:\CellDive\LCB004-N-P\LCB004-N-P_Final\LCB004-N-P_7.0.4_R000_Cy7_CD45-AF750_FINAL_AFR_F.ome.tif.
# 2025-11-18 14:01:36.111 | DEBUG    | plex_pipe.core_cutting.controller:cut_channel:93 - Cut and saved core Core_000, channel CD45.
# 2025-11-18 14:01:36.115 | DEBUG    | plex_pipe.core_cutting.controller:cut_channel:100 - Closed file handle for channel CD45.
# 2025-11-18 14:01:36.115 | INFO     | plex_pipe.core_cutting.controller:try_assemble_ready_cores:106 - Assembling full core Core_000
# INFO     The Zarr backing store has been changed from None the new file path:
#          C:\sdata_toy_example\LCB004-N-P_Analysis\cores\Core_000.zarr
# 2025-11-18 14:01:38.532 | INFO     | plex_pipe.core_cutting.assembler:assemble_core:113 - Core 'Core_000' assembled with channels: ['AP2B', 'AR', 'CD45', 'CK14', 'CK818', 'DAPI', 'ECad', 'ER', 'FOXA1', 'GATA3', 'HER2', 'ProgRc', 'SMA']
# 2025-11-18 14:01:38.532 | INFO     | plex_pipe.core_cutting.controller:run:137 - All channels processed and cores assembled.
